# %% [markdown]
# ### 1. Importing basic liabraries

# %%
import pandas as pd
import numpy as np
## For Data Visualization 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set()
## For Standardization and other
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
## Models
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
#ignore warnings
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### 2. Importing data

# %%
df = pd.read_csv('data.xls')
df.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# 2        1     7            1
# 3        0     7            1
# 4        0     8            1

# %% [markdown]
# ### 3. Infomation about data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       299 non-null    float64
#  1   anaemia                   299 non-null    int64
#  2   creatinine_phosphokinase  299 non-null    int64
#  3   diabetes                  299 non-null    int64
#  4   ejection_fraction         299 non-null    int64
#  5   high_blood_pressure       299 non-null    int64
#  6   platelets                 299 non-null    float64
#  7   serum_creatinine          299 non-null    float64
#  8   serum_sodium              299 non-null    int64
#  9   sex                       299 non-null    int64
#  10  smoking                   299 non-null    int64
#  11  time                      299 non-null    int64
#  12  DEATH_EVENT               299 non-null    int64
# dtypes: float64(3), int64(10)
# memory usage: 30.5 KB

# %% [markdown]
# ### Observations:
# - #####  The dataset contains 299 rows and 13 columns.
# - ##### There is no categorical variables in this data.

# %% [markdown]
# ### 4. Descriptive Statistics

# %%
df.describe()
# Out:
#               age     anaemia  creatinine_phosphokinase    diabetes  \
# count  299.000000  299.000000                299.000000  299.000000
# mean    60.833893    0.431438                581.839465    0.418060
# std     11.894809    0.496107                970.287881    0.494067
# min     40.000000    0.000000                 23.000000    0.000000
# 25%     51.000000    0.000000                116.500000    0.000000
# 50%     60.000000    0.000000                250.000000    0.000000
# 75%     70.000000    1.000000                582.000000    1.000000
# max     95.000000    1.000000               7861.000000    1.000000
#
#        ejection_fraction  high_blood_pressure      platelets  \
# count         299.000000           299.000000     299.000000
# mean           38.083612             0.351171  263358.029264
# std            11.834841             0.478136   97804.236869
# min            14.000000             0.000000   25100.000000
# 25%            30.000000             0.000000  212500.000000
# 50%            38.000000             0.000000  262000.000000
# 75%            45.000000             1.000000  303500.000000
# max            80.000000             1.000000  850000.000000
#
#        serum_creatinine  serum_sodium         sex    smoking        time  \
# count         299.00000    299.000000  299.000000  299.00000  299.000000
# mean            1.39388    136.625418    0.648829    0.32107  130.260870
# std             1.03451      4.412477    0.478136    0.46767   77.614208
# min             0.50000    113.000000    0.000000    0.00000    4.000000
# 25%             0.90000    134.000000    0.000000    0.00000   73.000000
# 50%             1.10000    137.000000    1.000000    0.00000  115.000000
# 75%             1.40000    140.000000    1.000000    1.00000  203.000000
# max             9.40000    148.000000    1.000000    1.00000  285.000000
#
#        DEATH_EVENT
# count    299.00000
# mean       0.32107
# std        0.46767
# min        0.00000
# 25%        0.00000
# 50%        0.00000
# 75%        1.00000
# max        1.00000

# %% [markdown]
# ### Observations:
# - ##### The average age is 60.83 and the highest age is 95.
# - ##### The average value of creatinine_phosphokinase 581.83 and the highest value is 7861. So there might be some outliers in this variable.
# - ##### The average value of ejection_fraction is 38.08 and the highest value is 80.
# - ##### The average value of platelets is 263358.02 and the highest value is 850000.
# - ##### The average value of serum_creatinine is 1.39 and the highest value is 9.40.
# - ##### The average value of serum_sodium is 136.62 and the highest value is 148.
# - ##### The average value of time is 130.26 and the highest value is 285.

# %% [markdown]
# ### 5. Checking Null Values

# %%
df.isnull().sum()
# Out:
# age                         0
# anaemia                     0
# creatinine_phosphokinase    0
# diabetes                    0
# ejection_fraction           0
# high_blood_pressure         0
# platelets                   0
# serum_creatinine            0
# serum_sodium                0
# sex                         0
# smoking                     0
# time                        0
# DEATH_EVENT                 0
# dtype: int64

# %% [markdown]
# ### Observation:
# - ##### There is no null values in the dataset.

# %% [markdown]
# ### 6. Data Visualization:

# %% [markdown]
# ### I. For Categorical Variables:

# %% [markdown]
# #### i. Checking number of male and females in data:

# %%
df_sex = df['sex']
df_sex = df_sex.map({1:'male',0:'female'})

# %%
plt.title('Frequency of Sex Variable')
sns.barplot(x = df_sex.value_counts().index, y = df_sex.value_counts().values)
plt.show()

# %% [markdown]
# ### Observation:
# - ##### It is clear that there are much more male than females in this dataset.

# %% [markdown]
# #### ii. Checking number anaemia cases:

# %%
df_anaemia = df['anaemia']
df_anaemia = df_anaemia.map({1:'Yes',0:'No'})

# %%
plt.title('Number of anaemia cases')
sns.barplot(x = df_anaemia.value_counts().index, y = df_anaemia.value_counts().values)
plt.show()

# %% [markdown]
# ### Observation:
# - ##### It is clear that the presence of anaemia is less.

# %% [markdown]
# #### iii. Checking number diabetes cases:

# %%
df_diabetes = df['diabetes']
df_diabetes = df_diabetes.map({1:'Yes',0:'No'})

# %%
plt.title('Number of Diabetes cases')
sns.barplot(x = df_diabetes.value_counts().index, y = df_diabetes.value_counts().values)
plt.show()

# %% [markdown]
# ### Observation:
# - ##### It is clear that the presence of diabetes is less.

# %% [markdown]
# #### iv. Checking number high blood pressure cases:

# %%
df_high_blood_pressure = df['high_blood_pressure']
df_high_blood_pressure = df_high_blood_pressure.map({1:'Yes',0:'No'})

# %%
plt.title('Number of High Blood Pressure Cases')
sns.barplot(x = df_high_blood_pressure.value_counts().index, y = df_high_blood_pressure.value_counts().values)
plt.show()

# %% [markdown]
# ### Observation:
# - ##### It is clear that the presence of high blood pressure  is less.

# %% [markdown]
# #### v. Checking number smoking cases:

# %%
df_smoking = df['smoking']
df_smoking = df_smoking.map({1:'Yes',0:'No'})

# %%
plt.title('Number of Smoking Cases')
sns.barplot(x = df_smoking.value_counts().index, y = df_smoking.value_counts().values)
plt.show()

# %% [markdown]
# ### Observation:
# - ##### It is clear that the presence of smoking  is less.

# %% [markdown]
# #### vi. Checking number Death Event cases:

# %%
df_death = df['DEATH_EVENT']
df_death = df_death.map({1:'Yes',0:'No'})

# %%
plt.title('Number of Death Event Cases')
sns.barplot(x = df_death.value_counts().index, y = df_death.value_counts().values)
plt.show()

# %% [markdown]
# ### Observation:
# - ##### It is clear that the presence of deaths are less.

# %% [markdown]
# ### II. For Continuous Variables:

# %%
## Distribution of age
sns.distplot(df['age'],bins=20)
plt.show()

# %% [markdown]
# ### Observation:
# - ##### Age is not normally distributed bcs theres also value peek at age 70.

# %%
## DIstribution of creatinine_phosphokinase
sns.distplot(df['creatinine_phosphokinase'],bins=20)
plt.show()

# %% [markdown]
# ### Observation:
# - ##### creatinine_phosphokinase is right skewed and have some outliers.

# %%
## Distribution of ejection_fraction
sns.distplot(df['ejection_fraction'],bins=20)
plt.show()

# %% [markdown]
# ### Observation:
# - ##### Ejection_Fraction not normalized.

# %%
## Distribution of Platelets
sns.distplot(df['platelets'],bins=20)
plt.show()

# %% [markdown]
# ### Observation:
# - ##### Platelets is almost normalized and might have some outliers.

# %%
## serum_creatinine distribution
sns.distplot(df['serum_creatinine'],bins=20)
plt.show()

# %% [markdown]
# ### Observation:
# - ##### serum_creatinine is right skewed and have some outliers.

# %%
## serum_sodium distribution
sns.distplot(df['serum_sodium'],bins=20)
plt.show()

# %% [markdown]
# ### Observation:
# - ##### serum_sodium is almost normalized.

# %% [markdown]
# ### III. Checking Relationship with Target:

# %%
## Sex and death_event
sns.countplot(x=df_sex,hue=df_death)
plt.show()

# %% [markdown]
# ### Observation:
# - ##### Males are more dead than females.

# %%
## Anaemia and Death_EVENT
sns.countplot(x=df_anaemia,hue=df_death)
plt.show()

# %% [markdown]
# ### Observation:
# - ##### Presence of anameia also not have much affect or reason of death

# %%
## Diabetes and Death_EVENT
sns.countplot(x=df_diabetes,hue=df_death)
plt.show()

# %% [markdown]
# ### Observation:
# - ##### Presence of diabetes also not have much affect or reason of death

# %%
## High Blood Pressure and Death_EVENT
sns.countplot(x=df_high_blood_pressure,hue=df_death)
plt.show()

# %% [markdown]
# ### Observation:
# - ##### Presence of high blood pressure also not have much affect or reason of death

# %%
## Smoking and Death_EVENT
sns.countplot(x=df_smoking,hue=df_death)
plt.show()

# %% [markdown]
# ### Observation:
# - ##### Smoking  is also not a major or reason of death

# %% [markdown]
# ### Observation on relationship with target:
# - #### The reason is that beacuse we don't have much data and data is not balanced bcs there is much more no's than yes in our target variable.

# %% [markdown]
# ### IV. Checking Outliers

# %%
col = ['age', 'creatinine_phosphokinase','ejection_fraction','platelets',
       'serum_creatinine', 'serum_sodium', 'time']

# %%
for i in col:
    sns.boxplot(df[i])
    plt.show()

# %% [markdown]
# ### Observation:
# - ##### So we have some outliers in creatinine_phosphokinase, platelets, serum_creatinine, serum_sodium

# %%
sns.displot(x=df['age'],hue=df_sex,kind='kde',multiple='fill').set(
    title="density of the classes of 'sex' variable by age")
plt.show()

# %%
sns.displot(x=df['age'],hue=df_death,kind='kde',multiple='fill').set(
    title = "density of the classes of 'death_event' variable by age")
plt.show()

# %%
sns.lineplot(x=df['age'],y=df['time'],hue=df_sex)
# Out:
# <AxesSubplot:xlabel='age', ylabel='time'>

# %% [markdown]
# ### Observation:
# - ##### With the passage of time it shows that females used to live longer than males

# %% [markdown]
# ### V. Heatmap for Correlation

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df.corr(),annot=True,cmap="Blues")
plt.show()

# %% [markdown]
# ### Observation:
# - ##### age is highly correlated with death_event.
# - ##### serum_creatinine is highly correlated with death_event.
# - ##### Smoking is highly correlated with sex.
# - ##### ejection_fraction is correlated with serium_sodium.
# - ##### Age is correlated with serium_creatinine.

# %% [markdown]
# ### 7. Removing Outliers

# %%
df['creatinine_phosphokinase_zscore'] = (df['creatinine_phosphokinase']-df['creatinine_phosphokinase'].mean())/df['creatinine_phosphokinase'].std()
df['platelets_zscore'] = (df['platelets']-df['platelets'].mean())/df['platelets'].std()
df['serum_creatinine_zscore'] = (df['serum_creatinine']-df['serum_creatinine'].mean())/df['serum_creatinine'].std()
df['serum_sodium_zscore'] = (df['serum_sodium']-df['serum_sodium'].mean())/df['serum_sodium'].std()
df['ejection_fraction_zscore'] = (df['ejection_fraction']-df['ejection_fraction'].mean())/df['ejection_fraction'].std()

# %%
df.head()
print(df.shape)
# Out:
# (299, 18)

# %%
df_outliers = df[(df['creatinine_phosphokinase_zscore']>-3) & (df['creatinine_phosphokinase_zscore']<3)]

# %%
df_outliers.shape
# Out:
# (292, 18)

# %%
df_outliers2 = df_outliers[(df_outliers['platelets_zscore']>-3) & (df_outliers['platelets_zscore']<3)]

# %%
df_outliers2.shape
# Out:
# (289, 18)

# %%
df_outliers3 = df_outliers2[(df_outliers2['serum_creatinine_zscore']>-3) & (df_outliers2['serum_creatinine_zscore']<3)]

# %%
df_outliers3.shape
# Out:
# (284, 18)

# %%
df_outliers4 = df_outliers3[(df_outliers3['serum_sodium_zscore']>-3) & (df_outliers3['serum_sodium_zscore']<3)]

# %%
df_outliers4.shape
# Out:
# (281, 18)

# %%
df_outliers5 = df_outliers4[(df_outliers4['ejection_fraction_zscore']>-3) & (df_outliers4['ejection_fraction_zscore']<3)]

# %%
df_outliers5.shape
# Out:
# (280, 18)

# %%
final_df = df_outliers5.copy()

# %%
final_df.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 5  90.0        1                        47         0                 40
# 6  75.0        1                       246         0                 15
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1   265000.0               1.9           130    1
# 2                    0   162000.0               1.3           129    1
# 3                    0   210000.0               1.9           137    1
# 5                    1   204000.0               2.1           132    1
# 6                    0   127000.0               1.2           137    1
#
#    smoking  time  DEATH_EVENT  creatinine_phosphokinase_zscore  \
# 0        0     4            1                         0.000165
# 2        1     7            1                        -0.449186
# 3        0     7            1                        -0.485257
# 5        1     8            1                        -0.551217
# 6        0    10            1                        -0.346124
#
#    platelets_zscore  serum_creatinine_zscore  serum_sodium_zscore  \
# 0          0.016788                 0.489237            -1.501519
# 2         -1.036336                -0.090748            -1.728149
# 3         -0.545559                 0.489237             0.084892
# 5         -0.606907                 0.682565            -1.048259
# 6         -1.394193                -0.187412             0.084892
#
#    ejection_fraction_zscore
# 0                 -1.527998
# 2                 -1.527998
# 3                 -1.527998
# 5                  0.161928
# 6                 -1.950479

# %%
final_df.drop(['creatinine_phosphokinase_zscore', 'platelets_zscore',
       'serum_creatinine_zscore', 'serum_sodium_zscore',
       'ejection_fraction_zscore'],axis=1,inplace=True)

# %%
final_df.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 5  90.0        1                        47         0                 40
# 6  75.0        1                       246         0                 15
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1   265000.0               1.9           130    1
# 2                    0   162000.0               1.3           129    1
# 3                    0   210000.0               1.9           137    1
# 5                    1   204000.0               2.1           132    1
# 6                    0   127000.0               1.2           137    1
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 2        1     7            1
# 3        0     7            1
# 5        1     8            1
# 6        0    10            1

# %% [markdown]
# ### 8. Splitting data

# %%
X = final_df.drop('DEATH_EVENT',axis=1)
y = final_df['DEATH_EVENT']

# %%
X
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 5    90.0        1                        47         0                 40
# 6    75.0        1                       246         0                 15
# ..    ...      ...                       ...       ...                ...
# 293  63.0        1                       103         1                 35
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                      1   265000.0               1.9           130    1
# 2                      0   162000.0               1.3           129    1
# 3                      0   210000.0               1.9           137    1
# 5                      1   204000.0               2.1           132    1
# 6                      0   127000.0               1.2           137    1
# ..                   ...        ...               ...           ...  ...
# 293                    0   179000.0               0.9           136    1
# 294                    1   155000.0               1.1           143    1
# 295                    0   270000.0               1.2           139    0
# 297                    0   140000.0               1.4           140    1
# 298                    0   395000.0               1.6           136    1
#
#      smoking  time
# 0          0     4
# 2          1     7
# 3          0     7
# 5          1     8
# 6          0    10
# ..       ...   ...
# 293        1   270
# 294        1   270
# 295        0   271
# 297        1   280
# 298        1   285
#
# [280 rows x 12 columns]

# %%
y
# Out:
# 0      1
# 2      1
# 3      1
# 5      1
# 6      1
#       ..
# 293    0
# 294    0
# 295    0
# 297    0
# 298    0
# Name: DEATH_EVENT, Length: 280, dtype: int64

# %%
##Train Test Split
X_train,X_test,y_train,y_test = train_test_split(X,y,shuffle=True,test_size=0.2)

# %%
X_train.shape
# Out:
# (224, 12)

# %%
X_test.shape
# Out:
# (56, 12)

# %% [markdown]
# ### 9. Data Standardization

# %%
scaler = StandardScaler()
X_train_scaler = scaler.fit_transform(X_train)
X_test_scaler  = scaler.transform(X_test)

# %%
X_train_scaler
# Out:
# array([[-1.38481216, -0.92262651,  0.27369211, ...,  0.73812437,
#         -0.70947565, -0.88696393],
#        [ 0.3091782 , -0.92262651,  2.3848316 , ...,  0.73812437,
#          1.40949163,  1.65659124],
#        [-1.38481216,  1.08386221,  2.74368713, ...,  0.73812437,
#         -0.70947565, -0.52359891],
#        ...,
#        [-0.28371843,  1.08386221, -0.56045613, ...,  0.73812437,
#          1.40949163,  0.57995413],
#        [-0.70721602,  1.08386221, -0.32185538, ...,  0.73812437,
#         -0.70947565, -0.29481352],
#        [ 0.90207482,  1.08386221, -0.62726434, ...,  0.73812437,
#          1.40949163, -0.83313207]])

# %%
X_test_scaler
# Out:
# array([[ 0.73267578, -0.92262651, -0.70552539, -0.82717019,  0.17880367,
#         -0.75261781,  0.37374411,  0.67887272, -0.19710006, -1.35478524,
#         -0.70947565, -0.69855244],
#        [ 1.57967096, -0.92262651,  0.64400048,  1.20894105,  0.0098078 ,
#          1.32869564, -0.82214748,  0.03642452, -0.44102499, -1.35478524,
#         -0.70947565,  0.04163558],
#        [ 0.56327675,  1.08386221,  1.11165796,  1.20894105, -0.24368602,
#         -0.75261781,  0.11325288, -0.28479958, -0.68494993,  0.73812437,
#         -0.70947565,  0.94331915],
#        [ 0.22447868, -0.92262651, -0.56427374, -0.82717019, -1.08866539,
#         -0.75261781, -0.18275989,  1.80315706, -0.44102499,  0.73812437,
#         -0.70947565,  1.17210454],
#        [-0.53781698,  1.08386221,  4.49597109, -0.82717019, -0.24368602,
#          1.32869564, -1.42601353, -0.44541163,  0.77859968,  0.73812437,
#         -0.70947565,  1.06444083],
#        [-0.70721602,  1.08386221,  0.01409449, -0.82717019,  1.86876242,
#          1.32869564,  0.02276805, -0.44541163,  0.53467474,  0.73812437,
#         -0.70947565,  1.1855625 ],
#        [-0.36841795,  1.08386221, -0.59099703, -0.82717019, -0.6661757 ,
#         -0.75261781,  1.58147622, -0.44541163,  0.77859968, -1.35478524,
#         -0.70947565, -1.14266524],
#        [ 0.73267578, -0.92262651,  0.34240913, -0.82717019, -0.24368602,
#         -0.75261781,  0.77632148, -0.28479958,  1.26644954, -1.35478524,
#         -0.70947565,  1.58930142],
#        [-1.04601409, -0.92262651,  0.66881496, -0.82717019, -1.51115508,
#          1.32869564,  0.68159739, -0.28479958, -0.19710006,  0.73812437,
#          1.40949163, -0.96771171],
#        [-0.28371843,  1.08386221, -0.58336181, -0.82717019,  1.86876242,
#        [ 0.13977916,  1.08386221, -0.72079584,  1.20894105,  0.17880367,
#         -0.75261781, -0.47877266, -0.28479958,  0.77859968, -1.35478524,
#         -0.70947565, -0.55051483],
#        [ 0.3091782 , -0.92262651, -0.65780524,  1.20894105,  1.02378305,
#          1.32869564, -0.86950952, -0.44541163,  0.77859968,  0.73812437,
#         -0.70947565, -1.31761877],
#        [-0.11431939, -0.92262651, -0.22641507, -0.82717019, -0.24368602,
#         -0.75261781, -1.52073761,  0.19703657,  0.53467474,  0.73812437,
#         -0.70947565,  1.76425495],
#        [-0.53781698,  1.08386221, -0.51273598,  1.20894105,  0.17880367,
#         -0.75261781,  0.88288608, -0.12418753, -0.44102499,  0.73812437,
#         -0.70947565,  1.65659124],
#        [-1.46951167, -0.92262651, -0.6768933 ,  1.20894105,  0.17880367,
#          1.32869564, -0.31300551, -0.92724778,  0.53467474,  0.73812437,
#         -0.70947565, -0.64472058],
#        [ 0.90207482, -0.92262651, -0.59481464,  1.20894105,  1.02378305,
#          1.32869564, -0.5142942 , -0.44541163, -0.68494993,  0.73812437,
#         -0.70947565, -1.26378692],
#        [-1.63891071,  1.08386221, -0.67307569, -0.82717019, -0.24368602,
#         -0.75261781,  1.22626089, -0.28479958,  0.53467474,  0.73812437,
#          1.40949163,  0.99715101],
#        [-0.11431939,  1.08386221, -0.34666986,  1.20894105, -0.6661757 ,
#         -0.75261781, -1.31944893, -0.44541163,  0.04682488,  0.73812437,
#          1.40949163,  1.58930142],
#        [ 0.73267578, -0.92262651,  0.27369211, -0.82717019,  0.17880367,
#         -0.75261781, -2.4916595 ,  2.28499321, -0.19710006,  0.73812437,
#          1.40949163,  1.65659124],
#        [-1.38481216, -0.92262651,  0.27369211, -0.82717019, -1.51115508,
#          1.32869564, -1.60362119,  0.51826067, -0.44102499,  0.73812437,
#         -0.70947565,  0.71453377],
#        [-0.87661505, -0.92262651,  1.79691934, -0.82717019, -1.08866539,
#          1.32869564,  0.11325288, -0.60602368, -1.66064966,  0.73812437,
#         -0.70947565, -1.1964971 ],
#        [-0.96131457, -0.92262651,  0.27369211, -0.82717019,  1.02378305,
#         -0.75261781, -1.2839274 , -1.08785983, -0.68494993, -1.35478524,
#         -0.70947565,  0.60687006],
#        [ 1.74906999,  1.08386221, -0.11379552, -0.82717019,  1.02378305,
#         -0.75261781, -2.53902154,  0.03642452, -0.19710006,  0.73812437,
#         -0.70947565, -1.53294619]])

# %% [markdown]
# ### 10. Models

# %% [markdown]
# ### a. RandomForestClassifier

# %%
rf_model = RandomForestClassifier()
rf_model.fit(X_train_scaler,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = rf_model.predict(X_test_scaler)

# %%
print(accuracy_score(y_pred,y_test))
# Out:
# 0.8392857142857143

# %% [markdown]
# ### b. LogisticRegression

# %%
lr_model = LogisticRegression()
lr_model.fit(X_train_scaler,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = lr_model.predict(X_test_scaler)

# %%
print(accuracy_score(y_pred,y_test))
# Out:
# 0.8035714285714286

# %% [markdown]
# ### b. XGBOOST Classifier

# %%
xgb_model = XGBClassifier()
xgb_model.fit(X_train_scaler,y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, predictor='auto', random_state=0,
#               reg_alpha=0, reg_lambda=1, ...)

# %%
y_pred = xgb_model.predict(X_test_scaler)

# %%
print(accuracy_score(y_pred,y_test))
# Out:
# 0.875

# %%
print(classification_report(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.93      0.91        40
#            1       0.80      0.75      0.77        16
#
#     accuracy                           0.88        56
#    macro avg       0.85      0.84      0.84        56
# weighted avg       0.87      0.88      0.87        56

# %%
cm = confusion_matrix(y_pred,y_test)
cm
# Out:
# array([[37,  3],
#        [ 4, 12]], dtype=int64)

# %%
sns.heatmap(cm,annot=True,cmap='Blues')
# Out:
# <AxesSubplot:>
